# %% [markdown]
# ## Colab 기본 명령어

# %% [markdown]
# #### git 명령

# %%
# !git

# %% [markdown]
# #### Colab 서버 폴더 파일 리스트

# %%
# %ls

# %% [markdown]
# #### 현재 작업 폴더 경로

# %%
# %pwd
# Out:
# 'f:\\projects\\Book_AI_foundation\\1_3_setup'

# %% [markdown]
# ## Colab 내 디버깅 방법
# 참고: https://www.geeksforgeeks.org/debugging-in-google-colab/

# %%
# !pip install ipdb
# %pdb on
import ipdb
ipdb.set_trace()
