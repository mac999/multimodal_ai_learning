# %% [markdown]
# ### Google Colab 설치 방법
#
# 링크: https://developers.google.com/colab

# %% [markdown]
# #### 본인 구글 드라이브 데이터 접근을 위한 연결방법

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
target_folder = '/content/drive/MyDrive/07.Book/AI_start/github'
os.chdir(target_folder)
print(f"현재 작업 폴더: {os.getcwd()}")
print("폴더 내 파일 목록:", os.listdir())

# %%
from google.colab import files
data_to_load = files.upload()

# %% [markdown]
# #### NVIDIA GPU 체크 방법

# %%
# !nvidia-smi
# !nvcc -V
# Out:
# Thu Oct 16 15:17:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.61                 Driver Version: 551.61         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P8             10W /  125W |       0MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# #### API Key 설정 방법
# 사전 해당 웹사이트 가입 후 API 키 토큰 확인 필요함.
# - hf-api (Hugging Face. 오픈웨이트 모델 사용시 필요): https://huggingface.co/settings/tokens
# - wandb (Weights & Biases. 학습 성능 로그 모니터링): https://wandb.ai/settings#apikeys
#
# API 키 토큰값 확인 후 Colab 사용자 데이터에 각각 다음과 같이 설정함.
#
# <img src="img_colab.png" height="300">
#
# 이후, Colab에서 다음 명령으로 키값 획득가능해짐.

# %%
from google.colab import userdata
key = userdata.get('openai-api')
key = userdata.get('hf-api')
key = userdata.get('travily-api')
key = userdata.get('gemini-api')
key = userdata.get('serp-api')
key = userdata.get('wandb')
key = userdata.get('langsmith')

# %% [markdown]
# 키 토큰 설정 후엔 다음과 같이 허깅페이스 등 로그인해서 BERT 같은 LLM 모델 다운로드 활용 가능해짐

# %%
from huggingface_hub import notebook_login

notebook_login()
