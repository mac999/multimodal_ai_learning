# %% [markdown]
# ## 파이썬 패키지 설치

# %% [markdown]
# PIP install 명령 기반 필수 패키지 설치

# %%
import sys
sys.version_info

# PyTorch 설치 (CUDA 11.8 지원 버전)
# pip install torch==2.7.0 torchvision==0.22.0 torchaudio==2.7.0 --index-url https://download.pytorch.org/whl/cu118

# 1. Hugging Face 및 LLM 코어 패키지
# !pip install transformers datasets accelerate peft bitsandbytes trl gensim qwen-vl-utils

# 2. LangChain 및 Vector DB 패키지
# !pip install langchain langchain-community langchain-openai chromadb sentencepiece tiktoken

# 3. 문서 처리 및 기타 유틸리티 (필요한 경우에만)
# !pip install pypdf pymupdf python-dotenv wandb torchinfo

# %% [markdown]
# 설치된 패키지 리스트 확인

# %%
# !pip list

# %% [markdown]
# ## 파치토치 모듈 체크

# %% [markdown]
# 설치 버전 체크

# %%
import torch
torch.cuda.is_available()
torch.__version__
# Out:
# '2.7.1+cu118'

# %% [markdown]
# 트랜스포머 버전 및 CUDA 체크

# %%
import transformers, torch
from transformers import pipeline

print(transformers.__version__)
print(torch.cuda.is_available())
# Out:
# 4.54.0
# True

# %% [markdown]
# ## 설치된 패키지 테스트

# %% [markdown]
# numpy, matplotlib 테스트

# %%
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %% [markdown]
# pandas 테스트

# %%
import pandas as pd

data = {'Unemployment_Rate': [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2],
        'Stock_Index_Price': [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]
       }

df = pd.DataFrame(data,columns=['Unemployment_Rate','Stock_Index_Price'])
df.to_csv("dataset.csv")

df = pd.read_csv("dataset.csv")
display(df)
# Out:
#    Unnamed: 0  Unemployment_Rate  Stock_Index_Price
# 0           0                6.1               1500
# 1           1                5.8               1520
# 2           2                5.7               1525
# 3           3                5.7               1523
# 4           4                5.8               1515
# 5           5                5.6               1540
# 6           6                5.5               1545
# 7           7                5.3               1560
# 8           8                5.2               1555
# 9           9                5.2               1565

# %% [markdown]
# ## Colab 에 파일 업로드 다운로드

# %% [markdown]
# 업로드 방법

# %%
from google.colab import files
data_to_load = files.upload()

# %% [markdown]
# 다운로드 방법

# %%
from google.colab import files
import shutil

# Replace 'your_file.txt' with the filename you want to download
files.download('your_file.txt')

# Replace 'your_folder' with the folder you want to download as a zip
shutil.make_archive('your_folder', 'zip', 'your_folder')
files.download('your_folder.zip')
